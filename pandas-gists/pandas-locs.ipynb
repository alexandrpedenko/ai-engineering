# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Boris'],
    'Age': [25, 30, 35, 16],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Boston']
}
df = pd.DataFrame(data)

# %%
row = df.loc[2]['City']
row
# Out:
# 'Chicago'

# %%
subset_rows = df.loc[1:2, ['Name', 'City']]
subset_rows
# Out:
#       Name         City
# 1      Bob  Los Angeles
# 2  Charlie      Chicago

# %%
mask = df['Age'] > 20
filtered = df.loc[mask].iloc[0:2,0:2]
filtered
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.iloc[1]
# Out:
# Name            Bob
# Age              30
# City    Los Angeles
# Name: 1, dtype: object
