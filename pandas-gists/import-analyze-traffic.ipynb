# %%
import pandas as pd

from notebook_utils import get_data_path

path = get_data_path("website_traffic_data.csv")
df = pd.read_csv(path)
# Out:
#     Source  SessionDuration
# 0  Organic             8.15
# 1  Organic            17.28
# 2   Direct             8.62
# 3     Paid            17.95
# 4     Paid            27.04

# %%
grouped_data = df.groupby('Source')
average_duration = grouped_data['SessionDuration'].mean()
average_duration
# Out:
# Source
# Direct      15.151364
# Organic     16.472609
# Paid        12.542083
# Referral    14.485333
# Social      17.070625
# Name: SessionDuration, dtype: float64
