# %%
import pandas as pd

from notebook_utils import get_data_path

path = get_data_path("slow_responses.csv")

df = pd.read_csv(path, parse_dates=['Date'])
df.head()
# Out:
#         Date                                          Prompt  \
# 0 2023-01-01    Generate a creative story about space travel
# 1 2023-01-04       Explain quantum computing in simple terms
# 2 2023-01-05       Explain quantum computing in simple terms
# 3 2023-01-06  Generate marketing copy for a new tech product
# 4 2023-01-07          Write a sci-fi short story set in 2050
#
#    Response Time (ms)  Tokens Generated
# 0                  62               287
# 1                  53               290
# 2                  75               392
# 3                  61               250
# 4                  87               370

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date                  datetime64[us]
# Prompt                           str
# Response Time (ms)             int64
# Tokens Generated               int64
# dtype: object

# %%
mask = df['Response Time (ms)'] > 70
slow_responses = df[mask]
slow_responses.to_csv('slow_responses.csv', index=False)
print("Filtered data saved")
# Out:
# Filtered data saved
