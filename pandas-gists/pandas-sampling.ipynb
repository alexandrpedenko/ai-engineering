# %%
import pandas as pd
from notebook_utils import get_data_path

path = get_data_path("slow_responses.csv")

df = pd.read_csv(path, parse_dates=['Date'])

# %%
random_row = df.sample()
random_row
# Out:
#          Date                                   Prompt  Response Time (ms)  \
# 53 2023-03-17  Describe the impact of AI on healthcare                  83
#
#     Tokens Generated
# 53               208

# %%
random_rows = df.sample(n=4, random_state=10)
random_rows
# Out:
#          Date                                          Prompt  \
# 38 2023-02-25                Explain blockchain for beginners
# 3  2023-01-06  Generate marketing copy for a new tech product
# 26 2023-02-07     Write a poem about the future of technology
# 41 2023-02-28   Create a recipe using plant-based ingredients
#
#     Response Time (ms)  Tokens Generated
# 38                  86               461
# 3                   61               250
# 26                  70               306
# 41                  86               276

# %%
fraction = df.sample(frac=0.1).sort_values(["Response Time (ms)"])
fraction
# Out:
#          Date                                          Prompt  \
# 20 2023-01-27                Explain blockchain for beginners
# 45 2023-03-08    Generate a creative story about space travel
# 11 2023-01-16    Generate a creative story about space travel
# 50 2023-03-13          Write a sci-fi short story set in 2050
# 48 2023-03-11        Outline the ethical considerations of AI
# 42 2023-03-01                Explain blockchain for beginners
# 55 2023-03-20  Generate marketing copy for a new tech product
#
#     Response Time (ms)  Tokens Generated
# 20                  67               314
# 45                  70               379
# 11                  81               486
# 50                  82               428
# 48                  88               377
# 42                  90               223
# 55                  94               286
